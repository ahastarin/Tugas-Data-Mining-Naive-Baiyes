# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('./data_naivebayes.xlsx')
data.head()
# Out:
#   Purchase      Day Discount Free Delivery
# 0      Buy  Holiday      Yes            No
# 1      Buy  Holiday       No           Yes
# 2      Buy  Weekend      Yes           Yes
# 3      Buy  Weekday       No            No
# 4      Buy  Holiday      Yes           Yes

# %%
data.shape
# Out:
# (20, 4)

# %%
data['Purchase'].value_counts()
# Out:
# Purchase
# Buy       13
# No Buy     7
# Name: count, dtype: int64

# %%
pYes =13/20
pNo = 7/20

print('Pyes =',pYes,'pNo =',pNo)
# Out:
# Pyes = 0.65 pNo = 0.35

# %%
pd.crosstab(data['Day'],data['Purchase'])
# Out:
# Purchase  Buy  No Buy
# Day
# Holiday     6       2
# Weekday     4       2
# Weekend     3       3

# %%
pHolidayNo = 2/7
pWeekDayNo = 2/7
pWeekedNo = 3/7

pHolidayYes = 6/13
pWeekdayYes = 4/13
pWeekendYes = 3/13

pHoliday = 8/20
pWeekday = 6/20
pWeekend = 6/20

print(pWeekdayYes)
# Out:
# 0.3076923076923077

# %%
pNoWeekday = (pWeekDayNo*pNo) / pWeekday
pNoWeekday
# Out:
# 0.3333333333333333

# %%
pYesWeekday = (pWeekdayYes * pYes) / pWeekday

pYesWeekday
# Out:
# 0.6666666666666667

# %%
pd.crosstab(data['Discount'],data['Purchase'])
# Out:
# Purchase  Buy  No Buy
# Discount
# No          5       4
# Yes         8       3

# %%
pNoDiscountNo = 4/7
pYesDiscountNo = 8/7

pNoDiscountYes = 5/13
pYesDiscountYes = 8/13

pNoDiscount = 9/20
pYesDiscount = 9/20

# %%
pd.crosstab(data['Free Delivery'],data['Purchase'])
# Out:
# Purchase       Buy  No Buy
# Free Delivery
# No               7       4
# Yes              6       3

# %%
pNoDeliveryNo = 4/7
pYesDeliveryNo = 3/7

pNoDeliveryYes = 7/13
pYesDeliveryYes = 6/13

pNoDelivery = 11/20
pYesDelivery = 9/20

# %%
PNoBuy1 = ((pHolidayNo*pYesDiscountNo*pYesDeliveryNo)*pNo) / (pHoliday*pYesDiscount*pYesDelivery)

PNoBuy1
# Out:
# 0.6046863189720331

# %%
PBuy2 = ((pHolidayYes*pYesDiscountYes*pYesDeliveryYes)*pYes) / (pHolidayNo*pYesDiscount*pYesDelivery)

PBuy2
# Out:
# 1.1045364891518743

# %%
pSum = PNoBuy1 + PBuy2

pSum
# Out:
# 1.7092228081239074

# %%
pBuy = (PBuy2/pSum) * 100
pBuy
# Out:
# 64.62214779150096

# %%
pNoBuy = (PNoBuy1*pSum) * 100

pNoBuy
# Out:
# 103.3543648147487
